# %% [markdown]
# # Análise de Dados com Python
#
# ### Desafio:
#
# Você trabalha em uma empresa de telecom e tem clientes de vários serviços diferentes, entre os principais: internet e telefone.
#
# O problema é que, analisando o histórico dos clientes dos últimos anos, você percebeu que a empresa está com Churn de mais de 26% dos clientes.
#
# Isso representa uma perda de milhões para a empresa.
#
# O que a empresa precisa fazer para resolver isso?
#
# Base de Dados: https://drive.google.com/drive/folders/1T7D0BlWkNuy_MDpUHuBG44kT80EmRYIs?usp=sharing <br>
# Link Original do Kaggle: https://www.kaggle.com/radmirzosimov/telecom-users-dataset

# %%
# Passo 1: Importar a base de dados
import pandas as pd
tabela = pd.read_csv("telecom_users.csv")
# Passo 2: Visualizar a base de dados
tabela = tabela.drop("Unnamed: 0", axis = 1)
display(tabela)
# - Entender quais as informações tão disponíveis
# - Descobrir as cagadas da base de dados
# Out:
#        IDCliente     Genero  Aposentado Casado Dependentes  ...    FormaPagamento ValorMensal TotalGasto Churn Codigo
# 0     7010-BRBUU  Masculino           0    Sim         Sim  ...     CartaoCredito       24.10    1734.65   Nao    NaN
# 1     9688-YGXVR   Feminino           0    Nao         Nao  ...     CartaoCredito       88.15     3973.2   Nao    NaN
# 2     9286-DOJGF   Feminino           1    Sim         Nao  ...  DebitoAutomatico       74.95    2869.85   Sim    NaN
# 3     6994-KERXL  Masculino           0    Nao         Nao  ...  BoletoEletronico       55.90      238.5   Nao    NaN
# 4     2181-UAESM  Masculino           0    Nao         Nao  ...  BoletoEletronico       53.45      119.5   Nao    NaN
# ...          ...        ...         ...    ...         ...  ...               ...         ...        ...   ...    ...
# 5981  0684-AOSIH  Masculino           0    Sim         Nao  ...  BoletoEletronico       95.00         95   Sim    NaN
# 5982  5982-PSMKW   Feminino           0    Sim         Sim  ...     CartaoCredito       91.10     2198.3   Nao    NaN
# 5983  8044-BGWPI  Masculino           0    Sim         Sim  ...  BoletoEletronico       21.15     306.05   Nao    NaN
# 5984  7450-NWRTR  Masculino           1    Nao         Nao  ...  BoletoEletronico       99.45    1200.15   Sim    NaN
# 5985  4795-UXVCJ  Masculino           0    Nao         Nao  ...     CartaoCredito       19.80      457.3   Nao    NaN
#
# [5986 rows x 22 columns]

# %% [markdown]
# ### Conclusões e Ações

# %% [markdown]
# Escreva aqui suas conclusões:
