# %% [markdown]
# ## Tarefas
# - 1.Fazer a leitura de todos os arquivos e juntar em um arquivo final.
# - 2.Retirar colunas desnecessarias(Região -sigla, CNPJ da Revenda, Nome da Rua,Numero Rua, Complemento, Bairro e Cep).
# - 3.Na colu na "Data de Coleta", mostrar apenas o ANO da data.
# - 4.Na tabela, na coluna "Produto" pegar apenas aonde é "GASOLINA".
# ### Componentes
# - site: //www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/serie-historica-de-precos-de-combustiveis
# - Pegar todos os arquivos de Combustíveis automotivos.

# %%
import pandas as pd

# %%
df = pd.read_csv('https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsas/ca/ca-2004-01.csv', sep = ';', encoding= 'utf8' )
df2 = pd.read_csv('https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsas/ca/ca-2004-02.csv', sep = ';', encoding = 'utf8')

# %%
df3 = pd.read_csv('https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsas/ca/ca-2005-01.csv', sep = ';', encoding = 'latin')

# %%
df3
# Out:
#        ï»¿Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                     SE             SP                    GUARULHOS
# 1                     SE             SP                    GUARULHOS
# 2                     SE             SP                    GUARULHOS
# 3                     SE             SP                     SOROCABA
# 4                     SE             SP                     SOROCABA
# ...                  ...            ...                          ...
# 912724                NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912725                NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912726                NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912727                NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912728                NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# 1                                AUTO POSTO SAKAMOTO LTDA
# 2                                AUTO POSTO SAKAMOTO LTDA
# 3       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 4       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# ...                                                   ...
# 912724                      AUTO POSTO PIRES PEREIRA LTDA
# 912725                      AUTO POSTO PIRES PEREIRA LTDA
# 912726                     AUTO POSTO 5 DE FEVEREIRO LTDA
# 912727                     AUTO POSTO 5 DE FEVEREIRO LTDA
# 912728                     AUTO POSTO 5 DE FEVEREIRO LTDA
#
#             CNPJ da Revenda                     Nome da Rua Numero Rua  \
# 0        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 1        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 2        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 3        00.003.188/0001-21          RUA HUMBERTO DE CAMPOS        306
# 4        00.003.188/0001-21          RUA HUMBERTO DE CAMPOS        306
# ...                     ...                             ...        ...
# 912724   02.253.236/0001-65      AVENIDA LINDEMBERG CARDOSO        667
# 912725   02.253.236/0001-65      AVENIDA LINDEMBERG CARDOSO        667
# 912726   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
# 912727   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
# 912728   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
#
#                 Complemento          Bairro        Cep   Produto  \
# 0       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580  GASOLINA
# 1       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580    ETANOL
# 2       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580    DIESEL
# 3                       NaN  JARDIM ZULMIRA  18061-000  GASOLINA
# 4                       NaN  JARDIM ZULMIRA  18061-000    ETANOL
# ...                     ...             ...        ...       ...
# 912724               COMODO         TAQUARI  46140-000    ETANOL
# 912725               COMODO         TAQUARI  46140-000    DIESEL
# 912726               COMODO          CENTRO  46140-000  GASOLINA
# 912727               COMODO          CENTRO  46140-000    ETANOL
# 912728               COMODO          CENTRO  46140-000    DIESEL
#
#        Data da Coleta Valor de Venda Valor de Compra Unidade de Medida  \
# 0          04/01/2005          2,257          1,9594        R$ / litro
# 1          04/01/2005          1,449          1,0962        R$ / litro
# 2          04/01/2005          1,579          1,4444        R$ / litro
# 3          04/01/2005           2,21            1,97        R$ / litro
# 4          04/01/2005           1,23            0,93        R$ / litro
# ...               ...            ...             ...               ...
# 912724     27/06/2005           1,98             NaN        R$ / litro
# 912725     27/06/2005           1,69             NaN        R$ / litro
# 912726     27/06/2005            2,5             NaN        R$ / litro
# 912727     27/06/2005           1,95             NaN        R$ / litro
# 912728     27/06/2005           1,69             NaN        R$ / litro
#
#                             Bandeira
# 0       PETROBRAS DISTRIBUIDORA S.A.
# 1       PETROBRAS DISTRIBUIDORA S.A.
# 2       PETROBRAS DISTRIBUIDORA S.A.
# 3                             BRANCA
# 4                             BRANCA
# ...                              ...
# 912724                    PETROBAHIA
# 912725                    PETROBAHIA
# 912726                    PETROBAHIA
# 912727                    PETROBAHIA
# 912728                    PETROBAHIA
#
# [912729 rows x 16 columns]

# %%
df4 = pd.concat([df, df2, df3])

# %%
df4
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                    GUARULHOS
# 1                  SE             SP                    GUARULHOS
# 2                  SE             SP                    GUARULHOS
# 3                  SE             SP                     SOROCABA
# 4                  SE             SP                     SOROCABA
# ...               ...            ...                          ...
# 912724            NaN             BA  LIVRAMENTO DE NOSSA SENHORA
# 912725            NaN             BA  LIVRAMENTO DE NOSSA SENHORA
# 912726            NaN             BA  LIVRAMENTO DE NOSSA SENHORA
# 912727            NaN             BA  LIVRAMENTO DE NOSSA SENHORA
# 912728            NaN             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# 1                                AUTO POSTO SAKAMOTO LTDA
# 2                                AUTO POSTO SAKAMOTO LTDA
# 3       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 4       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# ...                                                   ...
# 912724                      AUTO POSTO PIRES PEREIRA LTDA
# 912725                      AUTO POSTO PIRES PEREIRA LTDA
# 912726                     AUTO POSTO 5 DE FEVEREIRO LTDA
# 912727                     AUTO POSTO 5 DE FEVEREIRO LTDA
# 912728                     AUTO POSTO 5 DE FEVEREIRO LTDA
#
#             CNPJ da Revenda                     Nome da Rua Numero Rua  \
# 0        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 1        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 2        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 3        00.003.188/0001-21          RUA HUMBERTO DE CAMPOS        306
# 4        00.003.188/0001-21          RUA HUMBERTO DE CAMPOS        306
# ...                     ...                             ...        ...
# 912724   02.253.236/0001-65      AVENIDA LINDEMBERG CARDOSO        667
# 912725   02.253.236/0001-65      AVENIDA LINDEMBERG CARDOSO        667
# 912726   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
# 912727   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
# 912728   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
#
#                 Complemento          Bairro        Cep   Produto  \
# 0       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580  GASOLINA
# 1       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580    ETANOL
# 2       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580    DIESEL
# 3                       NaN  JARDIM ZULMIRA  18061-000  GASOLINA
# 4                       NaN  JARDIM ZULMIRA  18061-000    ETANOL
# ...                     ...             ...        ...       ...
# 912724               COMODO         TAQUARI  46140-000    ETANOL
# 912725               COMODO         TAQUARI  46140-000    DIESEL
# 912726               COMODO          CENTRO  46140-000  GASOLINA
# 912727               COMODO          CENTRO  46140-000    ETANOL
# 912728               COMODO          CENTRO  46140-000    DIESEL
#
#        Data da Coleta Valor de Venda Valor de Compra Unidade de Medida  \
# 0          11/05/2004          1,967          1,6623        R$ / litro
# 1          11/05/2004          0,899          0,6282        R$ / litro
# 2          11/05/2004          1,299          1,1704        R$ / litro
# 3          10/05/2004           1,85            1,67        R$ / litro
# 4          10/05/2004           0,78            0,48        R$ / litro
# ...               ...            ...             ...               ...
# 912724     27/06/2005           1,98             NaN        R$ / litro
# 912725     27/06/2005           1,69             NaN        R$ / litro
# 912726     27/06/2005            2,5             NaN        R$ / litro
# 912727     27/06/2005           1,95             NaN        R$ / litro
# 912728     27/06/2005           1,69             NaN        R$ / litro
#
#                             Bandeira ï»¿Regiao - Sigla
# 0       PETROBRAS DISTRIBUIDORA S.A.               NaN
# 1       PETROBRAS DISTRIBUIDORA S.A.               NaN
# 2       PETROBRAS DISTRIBUIDORA S.A.               NaN
# 3                             BRANCA               NaN
# 4                             BRANCA               NaN
# ...                              ...               ...
# 912724                    PETROBAHIA                NE
# 912725                    PETROBAHIA                NE
# 912726                    PETROBAHIA                NE
# 912727                    PETROBAHIA                NE
# 912728                    PETROBAHIA                NE
#
# [2109577 rows x 17 columns]

# %%
df.loc[df['Produto'] == 'GASOLINA']
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                    GUARULHOS
# 3                  SE             SP                     SOROCABA
# 6                  CO             DF                     BRASILIA
# 9                  NE             BA                     SALVADOR
# 12                 SE             RJ                      NITEROI
# ...               ...            ...                          ...
# 281519             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 281521             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 281523             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 281524             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 281526             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# 3       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 6                    GASOL COMBUSTÍVEIS AUTOMOTIVOS LTDA.
# 9                            PETROBRAS DISTRIBUIDORA S.A.
# 12                           PETROBRAS DISTRIBUIDORA S.A.
# ...                                                   ...
# 281519                              JOSÉ TANAJURA MACHADO
# 281521                    IRMAS TRINDADE DE OLIVEIRA LTDA
# 281523             COMERCIO DE LUBRIFICANTES GRAVATA LTDA
# 281524                         JORGE TRINDADE DE OLIVEIRA
# 281526                      AUTO POSTO PIRES PEREIRA LTDA
#
#             CNPJ da Revenda                                  Nome da Rua  \
# 0        49.051.667/0001-02                     RODOVIA PRESIDENTE DUTRA
# 3        00.003.188/0001-21                       RUA HUMBERTO DE CAMPOS
# 6        00.603.738/0001-43  QI-QUADRA INTERNA 18  LOTES 47, 49, 51 E 53
# 9        34.274.233/0015-08                            RUA EDISTIO PONDE
# 12       34.274.233/0033-81                     AVENIDA ROBERTO SILVEIRA
# ...                     ...                                          ...
# 281519   14.696.785/0001-93                   AVENIDA LINDENBERG CARDOSO
# 281521   15.241.573/0001-84                              AVENIDA BRUMADO
# 281523   13.965.173/0001-96                     AVENIDA LEONIDAS CARDODO
# 281524   04.512.720/0001-97                              PRACA BOM JESUS
# 281526   02.253.236/0001-65                   AVENIDA LINDEMBERG CARDOSO
#
#        Numero Rua          Complemento          Bairro        Cep   Produto  \
# 0             S/N  KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580  GASOLINA
# 3             306                  NaN  JARDIM ZULMIRA  18061-000  GASOLINA
# 6             S/N                  NaN      TAGUATINGA  72315-000  GASOLINA
# 9             474                  NaN           STIEP  41770-395  GASOLINA
# 12            205                  NaN          ICARAÍ  24230-151  GASOLINA
# ...           ...                  ...             ...        ...       ...
# 281519        171               COMODO         TAQUARI  46140-000  GASOLINA
# 281521        272                 CASA         TAQUARI  46140-000  GASOLINA
# 281523        634                  NaN          CENTRO  46140-000  GASOLINA
# 281524         55                  NaN          CENTRO  46140-000  GASOLINA
# 281526        667               COMODO         TAQUARI  46140-000  GASOLINA
#
#        Data da Coleta Valor de Venda Valor de Compra Unidade de Medida  \
# 0          11/05/2004          1,967          1,6623        R$ / litro
# 3          10/05/2004           1,85            1,67        R$ / litro
# 6          10/05/2004           2,03          1,7021        R$ / litro
# 9          11/05/2004           1,91          1,7059        R$ / litro
# 12         10/05/2004          2,039          1,7916        R$ / litro
# ...               ...            ...             ...               ...
# 281519     28/06/2004           2,25             NaN        R$ / litro
# 281521     28/06/2004           2,23            1,79        R$ / litro
# 281523     28/06/2004           2,27             NaN        R$ / litro
# 281524     28/06/2004           2,24            1,79        R$ / litro
# 281526     28/06/2004            2,2            1,89        R$ / litro
#
#                             Bandeira
# 0       PETROBRAS DISTRIBUIDORA S.A.
# 3                             BRANCA
# 6       PETROBRAS DISTRIBUIDORA S.A.
# 9       PETROBRAS DISTRIBUIDORA S.A.
# 12      PETROBRAS DISTRIBUIDORA S.A.
# ...                              ...
# 281519                          CBPI
# 281521                        BRANCA
# 281523                          CBPI
# 281524                        BRANCA
# 281526                    PETROBAHIA
#
# [100031 rows x 16 columns]
